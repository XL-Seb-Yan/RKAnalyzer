# %%
import ROOT
from ROOT import TFile, TH1F, TCanvas, TMath,TLine, TH1
import copy
import array
ROOT.gStyle.SetOptStat(0)
ROOT.disableJSVis()
ROOT.gStyle.SetPadTickX(1)
ROOT.gStyle.SetPadTickY(1)
ROOT.gStyle.SetOptStat(0)
ROOT.gStyle.SetBarWidth(1);
ROOT.gStyle.SetHistLineWidth(1);
import sys
sys.path.append("/eos/home-x/xuyan/TrijetProj/TrijetAna/ZprimeAna/utiles")
from CMSStyle import CMS_lumi

# %%
file = TFile.Open(f"BParkingNANO_Run3_mc_124X.root")
tree = file.Get("Events")
# tree.Print()
# canvas = TCanvas("canvas", "Title", 800, 600)

# hist = TH1F("hist", "Kstar_charge", 500, -3, 3)

# tree.Draw("PV_x>>hist")
# print(hist.GetEntries())

# hist.Draw()
# canvas.Draw()
# Out:
# Error in <TNetXNGFile::Open>: [ERROR] Server responded with an error: [3010] Unable to give access - user access restricted - unauthorized identity used ; Permission denied

# %%
file = TFile("outputHits_0.root")
print(file)
file.ls()
hist1_1 = file.Get("hist1_1")
hist1_2 = file.Get("hist1_2")
hist1_3 = file.Get("hist1_3")
hist1_4 = file.Get("hist1_4")
hist1_5 = file.Get("hist1_5")
hist1_6 = file.Get("hist1_6")
hist1_7 = file.Get("hist1_7")
hist1_8 = file.Get("hist1_8")
hist1_9 = file.Get("hist1_9")
hist1_10 = file.Get("hist1_10")
hist1_11 = file.Get("hist1_11")
hist1_12 = file.Get("hist1_12")
hist1_13 = file.Get("hist1_13")
hist1_14 = file.Get("hist1_14")
hist1_15 = file.Get("hist1_15")
hist1_16 = file.Get("hist1_16")
hist1_17 = file.Get("hist1_17")
hist1_18 = file.Get("hist1_18")
hist1_19 = file.Get("hist1_19")
hist1_20 = file.Get("hist1_20")
hist1_21 = file.Get("hist1_21")
hist1_22 = file.Get("hist1_22")
hist1_23 = file.Get("hist1_23")
hist1_24 = file.Get("hist1_24")
hist1_25 = file.Get("hist1_25")

hist2_1 = file.Get("hist2_1")
hist2_2 = file.Get("hist2_2")
hist2_3 = file.Get("hist2_3")
hist2_4 = file.Get("hist2_4")
hist2d_1_1 = file.Get("hist2d_1_1")
hist2d_1_2 = file.Get("hist2d_1_2")
hist1_1.Rebin(5)
hist1_2.Rebin(5)
hist1_3.Rebin(5)
hist1_4.Rebin(5)
hist1_5.Rebin(5)
hist1_6.Rebin(5)
hist1_7.Rebin(5)
hist1_8.Rebin(5)
hist1_9.Rebin(5)
hist1_10.Rebin(5)
hist1_11.Rebin(5)
hist1_12.Rebin(5)
hist1_13.Rebin(5)
hist1_14.Rebin(5)
hist1_15.Rebin(5)
hist1_16.Rebin(5)
hist1_17.Rebin(5)
hist1_18.Rebin(5)
hist1_19.Rebin(5)
hist1_20.Rebin(5)
hist1_21.Rebin(5)
hist1_22.Rebin(5)
hist1_23.Rebin(5)
hist1_24.Rebin(5)
hist1_25.Rebin(5)

hist2_1.Rebin(2)
hist2_2.Rebin(2)
hist2_3.Rebin(2)
hist2_4.Rebin(2)
print(hist1_1.GetEntries())
print(hist2_1.GetEntries())
# Out:
# Name: outputHits_0.root Title:
# 40330.0
# 2335.0
# TFile**		outputHits_0.root
#  TFile*		outputHits_0.root
#   KEY: TH1F	hist1_1;1	B mass (all triplet)
#   KEY: TH1F	hist1_2;1	ll mass (all triplet)
#   KEY: TH1F	hist1_3;1	l1 p_{T} (all triplet)
#   KEY: TH1F	hist1_4;1	l2 p_{T} (all triplet)
#   KEY: TH1F	hist1_5;1	l1 p_{T} normalized (all triplet)
#   KEY: TH1F	hist1_6;1	l2 p_{T} normalized (all triplet)
#   KEY: TH1F	hist1_7;1	K p_{T} (all triplet)
#   KEY: TH1F	hist1_8;1	K p_{T} normalized (all triplet)
#   KEY: TH1F	hist1_9;1	B p_{T} (all triplet)
#   KEY: TH1F	hist1_10;1	B p_{T} normalized (all triplet)
#   KEY: TH1F	hist1_11;1	cos #alpha_{3D} (all triplet)
#   KEY: TH1F	hist1_12;1	Prob(SV fit) (all triplet)
#   KEY: TH1F	hist1_13;1	sig(Lxy) (all triplet)
#   KEY: TH1F	hist1_14;1	#Delta z (l1, K) (all triplet)
#   KEY: TH1F	hist1_15;1	#Delta z (l2, K) (all triplet)
#   KEY: TH1F	hist1_16;1	SigImpactParam(K, ll) (all triplet)
#   KEY: TH1F	hist1_17;1	#Delta R (ll) (all triplet)
# ...

# %%
def draw(c0, hist, xTitle, ipad):
    c0.cd(ipad)
    
    hist.GetYaxis().SetTitle("Events")
    hist.GetYaxis().SetTitleOffset(1.6)
    hist.GetYaxis().SetRangeUser(0.5,100000)
    hist.GetXaxis().SetTitle(xTitle)
    hist.SetTitle(hist.GetTitle())
    hist.SetLineWidth(1)
    hist.Draw("SAME")
    
    gPad.SetLogy()
    
from ROOT import gStyle, TLegend, TPad, gPad
gStyle.SetOptStat(110000)
c0 = TCanvas("","",2400,1800)
c0.cd()
c0.Divide(5,5)

draw(c0, hist1_1, "m_{B} [GeV]", 1)
draw(c0, hist1_2, "m_{ll} [GeV]", 2)
draw(c0, hist1_3, "p_{T}^{e1} [GeV]", 3)
draw(c0, hist1_4, "p_{T}^{e2} [GeV]", 4)
draw(c0, hist1_5, "p_{T}^{e1} (normalized)", 5)
draw(c0, hist1_6, "p_{T}^{e2} (normalized)", 6)
draw(c0, hist1_7, "p_{T}^{K} [GeV]", 7)
draw(c0, hist1_8, "p_{T}^{K} (normalized)", 8)
draw(c0, hist1_9, "p_{T}^{B} [GeV]", 9)
draw(c0, hist1_10, "p_{T}^{B} (normalized)", 10)
draw(c0, hist1_11, "cos #alpha_{3D}", 11)
draw(c0, hist1_12, "Probability", 12)
draw(c0, hist1_13, "Sig(Lxy)", 13)
draw(c0, hist1_14, "#Delta z (e1, K)", 14)
draw(c0, hist1_15, "#Delta z (e2, K)", 15)
draw(c0, hist1_16, "SigImpactParam(K, ll)", 16)
draw(c0, hist1_17, "#Delta R (ee)", 17)
draw(c0, hist1_18, "#Delta R (e1, K)", 18)
draw(c0, hist1_19, "#Delta R (e2, K)", 19)
draw(c0, hist1_20, "Momentum asymmetry", 20)
draw(c0, hist1_21, "Electron ID e1", 21)
draw(c0, hist1_22, "Electron ID e2", 22)
draw(c0, hist1_23, "Isolation l1_iso04_dca [GeV]", 23)
draw(c0, hist1_24, "Isolation l1_iso04_dca [GeV]", 24)
draw(c0, hist1_25, "Isolation l1_iso04_dca [GeV]", 25)

c0.SetLogy()
c0.Draw()
c0.Print("var.svg")
# Out:
# Info in <TCanvas::Print>: SVG file var.svg has been created

# %%
from ROOT import gStyle, TLegend
gStyle.SetOptStat(0)
c0 = TCanvas("","",1200,900)
c0.cd()

leg = TLegend(0.7, 0.8, 0.9, 0.9)

leg.AddEntry(hist1_1, "B (all triplets)", "l")
leg.AddEntry(hist1_3, "B (cleaned triplets)", "l")

hist1_1.SetLineColor(4)
hist1_3.SetLineColor(2)

hist1_1.GetYaxis().SetTitle("Events")
hist1_1.GetYaxis().SetTitleOffset(1.6)
hist1_1.GetYaxis().SetRangeUser(0,2000)
# hist5.GetYaxis().SetRangeUser(0,6000)
hist1_1.GetXaxis().SetRangeUser(3.5,7)
hist1_1.GetXaxis().SetTitle("m_{B} [GeV]")
hist1_1.SetTitle("")

hist1_1.Draw("SAME")
hist1_3.Draw("SAME")

leg.Draw()

# c0.SetLogy()
c0.Draw()

# %%
c0 = TCanvas("","",1200,900)
c0.cd()

leg = TLegend(0.1, 0.8, 0.4, 0.9)

leg.AddEntry(hist1_2, "B", "l")
leg.AddEntry(hist1_4, "B (no K*)", "l")

hist1_2.SetLineColor(4)
hist1_4.SetLineColor(2)

hist1_2.GetYaxis().SetTitle("Events")
hist1_2.GetYaxis().SetTitleOffset(1.6)
hist1_2.GetYaxis().SetRangeUser(0,20000)
# hist5.GetYaxis().SetRangeUser(0,6000)
# hist5.GetXaxis().SetRangeUser(, 4.4)
hist1_2.GetXaxis().SetTitle("m_{ee} [GeV]")
hist1_2.SetTitle("")

hist1_2.Draw("SAME")
hist1_4.Draw("SAME")

leg.Draw()

# c0.SetLogy()
c0.Draw()

# %%
c0 = TCanvas("","",1200,900)
c0.cd()

leg = TLegend(0.7, 0.8, 0.9, 0.9)

leg.AddEntry(hist2_1, "B (K*ll)", "l")

hist2_1.SetLineColor(4)

hist2_1.GetYaxis().SetTitle("Events")
hist2_1.GetYaxis().SetTitleOffset(1.6)
hist2_1.GetYaxis().SetRangeUser(0,200)
# hist2_1.GetXaxis().SetRangeUser(3.5,7)
hist2_1.GetXaxis().SetTitle("m_{B} [GeV]")
hist2_1.SetTitle("")

hist2_1.Draw("")

leg.Draw()

# c0.SetLogy()
c0.Draw()

# %%
c0 = TCanvas("","",1200,900)
c0.cd()

leg = TLegend(0.8, 0.8, 0.9, 0.9)

leg.AddEntry(hist2_2, "K*", "l")

hist2_2.SetLineColor(2)

hist2_2.GetYaxis().SetTitle("Events")
hist2_2.GetYaxis().SetTitleOffset(1.6)
hist2_2.GetYaxis().SetRangeUser(0,2000)
hist2_2.GetXaxis().SetRangeUser(0.6,1.2)
hist2_2.GetXaxis().SetTitle("m_{K*} [GeV]")
hist2_2.SetTitle("")

hist2_2.Draw("SAME")

leg.Draw()

# c0.SetLogy()
c0.Draw()

# %%
c0 = TCanvas("","",1200,900)
c0.cd()

leg = TLegend(0.8, 0.8, 0.9, 0.9)

leg.AddEntry(hist1_5, "l1", "l")
leg.AddEntry(hist1_6, "l2", "l")

hist1_5.SetLineColor(2)
hist1_6.SetLineColor(4)

hist1_5.GetYaxis().SetTitle("Events")
hist1_5.GetYaxis().SetTitleOffset(1.6)
hist1_5.GetYaxis().SetRangeUser(0,200)
# hist1_5.GetXaxis().SetRangeUser(0,5)
hist1_5.GetXaxis().SetTitle("pT [GeV]")
hist1_5.SetTitle("")

hist1_5.Draw("SAME")
hist1_6.Draw("SAME")

leg.Draw()

# c0.SetLogy()
c0.Draw()

# %%
c0 = TCanvas("","",1600,900)
c0.cd()

hist2d_1_2.GetXaxis().SetTitle("triplets")
hist2d_1_2.GetYaxis().SetTitle("quadruplets")
hist2d_1_2.SetTitle("")

hist2d_1_2.Draw("colorz text")

c0.SetLogz()
c0.Draw()
